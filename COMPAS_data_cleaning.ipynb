# %% [markdown]
# <a href="https://colab.research.google.com/github/MDankloff/ClusterCompas/blob/main/COMPAS_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings("ignore")
import os

# Specify the directory path
directory_path = '//Users/mirthedankloff/Documents/XAI_Bias_Error/COMPAS'

# Traverse the directory and print the names of all files
for dirname, _, filenames in os.walk(directory_path):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
compas_2 = pd.read_csv('/content/compas-scores-two-years.csv')

columns_to_remove = ['first','last', 'dob', 'compas_screening_date', 'juv_fel_count', 'juv_misd_count', 'juv_other_count', 'days_b_screening_arrest', 'c_jail_in', 'c_jail_out', 'c_case_number', 'c_offense_date', 'c_arrest_date', 'c_days_from_compas',
                     'c_charge_degree', 'c_charge_desc', 'r_case_number', 'r_charge_degree', 'r_days_from_arrest', 'r_offense_date', 'r_charge_desc', 'r_jail_in', 'r_jail_out', 'violent_recid', 'vr_case_number', 'vr_charge_degree', 'vr_offense_date',
                     'vr_charge_desc', 'screening_date', 'v_screening_date', 'in_custody', 'out_custody', 'start', 'end', 'decile_score.1', 'v_score_text']
compas_2 = compas_2.drop(columns=columns_to_remove)
compas_2.head()
#print(compas_2)
# Out:
#    id                name   sex  age          age_cat              race  \
# 0   1    miguel hernandez  Male   69  Greater than 45             Other
# 1   3         kevon dixon  Male   34          25 - 45  African-American
# 2   4            ed philo  Male   24     Less than 25  African-American
# 3   5         marcu brown  Male   23     Less than 25  African-American
# 4   6  bouthy pierrelouis  Male   43          25 - 45             Other
#
#    decile_score  priors_count  is_recid  is_violent_recid  type_of_assessment  \
# 0             1             0         0                 0  Risk of Recidivism
# 1             3             0         1                 1  Risk of Recidivism
# 2             4             4         1                 0  Risk of Recidivism
# 3             8             1         0                 0  Risk of Recidivism
# 4             1             2         0                 0  Risk of Recidivism
#
#   score_text v_type_of_assessment  v_decile_score  priors_count.1  event  \
# 0        Low     Risk of Violence               1               0      0
# 1        Low     Risk of Violence               1               0      1
# 2        Low     Risk of Violence               3               4      0
# 3       High     Risk of Violence               6               1      0
# 4        Low     Risk of Violence               1               2      0
#
#    two_year_recid
# 0               0
# 1               1
# 2               1
# 3               0
# 4               0

# %%
if compas_2['is_recid'].equals(compas_2['two_year_recid']):
  print("same")
else:
  print("not same")

missing_values = compas_2.isna()
print(missing_values.sum())
# Out:
# not same
# id                      0
# name                    0
# sex                     0
# age                     0
# age_cat                 0
# race                    0
# decile_score            0
# priors_count            0
# is_recid                0
# is_violent_recid        0
# type_of_assessment      0
# score_text              0
# v_type_of_assessment    0
# v_decile_score          0
# priors_count.1          0
# event                   0
# two_year_recid          0
# dtype: int64

# %%
compas_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7214 entries, 0 to 7213
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    7214 non-null   int64
#  1   name                  7214 non-null   object
#  2   sex                   7214 non-null   object
#  3   age                   7214 non-null   int64
#  4   age_cat               7214 non-null   object
#  5   race                  7214 non-null   object
#  6   decile_score          7214 non-null   int64
#  7   priors_count          7214 non-null   int64
#  8   is_recid              7214 non-null   int64
#  9   is_violent_recid      7214 non-null   int64
#  10  type_of_assessment    7214 non-null   object
#  11  score_text            7214 non-null   object
#  12  v_type_of_assessment  7214 non-null   object
#  13  v_decile_score        7214 non-null   int64
#  14  priors_count.1        7214 non-null   int64
#  15  event                 7214 non-null   int64
#  16  two_year_recid        7214 non-null   int64
# dtypes: int64(10), object(7)
# memory usage: 958.2+ KB

# %%
target1 = "two_year_recid"
target2 = "is_recid"

X1 = compas_2.drop([target1],axis=1)
Y1 = compas_2[target1]

X2 = compas_2.drop([target2],axis=1)
Y2 = compas_2[target2]

print(compas_2)
# Out:
#          id                 name     sex  age          age_cat  \
# 0         1     miguel hernandez    Male   69  Greater than 45
# 1         3          kevon dixon    Male   34          25 - 45
# 2         4             ed philo    Male   24     Less than 25
# 3         5          marcu brown    Male   23     Less than 25
# 4         6   bouthy pierrelouis    Male   43          25 - 45
# ...     ...                  ...     ...  ...              ...
# 7209  10996        steven butler    Male   23     Less than 25
# 7210  10997      malcolm simmons    Male   23     Less than 25
# 7211  10999      winston gregory    Male   57  Greater than 45
# 7212  11000          farrah jean  Female   33          25 - 45
# 7213  11001  florencia sanmartin  Female   23     Less than 25
#
#                   race  decile_score  priors_count  is_recid  \
# 0                Other             1             0         0
# 1     African-American             3             0         1
# 2     African-American             4             4         1
# 3     African-American             8             1         0
# 4                Other             1             2         0
# ...                ...           ...           ...       ...
# 7209  African-American             7             0         0
# 7210  African-American             3             0         0
# 7211             Other             1             0         0
# 7212  African-American             2             3         0
# 7213          Hispanic             4             2         1
#
#       is_violent_recid  type_of_assessment score_text v_type_of_assessment  \
# 0                    0  Risk of Recidivism        Low     Risk of Violence
# 1                    1  Risk of Recidivism        Low     Risk of Violence
# 2                    0  Risk of Recidivism        Low     Risk of Violence
# 3                    0  Risk of Recidivism       High     Risk of Violence
# 4                    0  Risk of Recidivism        Low     Risk of Violence
# ...                ...                 ...        ...                  ...
# 7209                 0  Risk of Recidivism     Medium     Risk of Violence
# 7210                 0  Risk of Recidivism        Low     Risk of Violence
# 7211                 0  Risk of Recidivism        Low     Risk of Violence
# 7212                 0  Risk of Recidivism        Low     Risk of Violence
# 7213                 0  Risk of Recidivism        Low     Risk of Violence
#
#       v_decile_score  priors_count.1  event  two_year_recid
# 0                  1               0      0               0
# 1                  1               0      1               1
# 2                  3               4      0               1
# 3                  6               1      0               0
# 4                  1               2      0               0
# ...              ...             ...    ...             ...
# 7209               5               0      0               0
# 7210               5               0      0               0
# 7211               1               0      0               0
# 7212               2               3      0               0
# 7213               4               2      0               1
#
# [7214 rows x 17 columns]

# %%
compas_2.to_csv('cleaned_compas_data.csv', index=False)

/content/cleaned_compas_data.csv
